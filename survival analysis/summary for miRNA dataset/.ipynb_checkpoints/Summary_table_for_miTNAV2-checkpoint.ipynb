# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import pandas as pd

# %% [markdown]
# #Gerneral Function for all

# %%
def Summary(filename):
    with open(filename,'rt') as raw_data:
        data=np.loadtxt(raw_data,delimiter=',')
  
    #count censored and uncensored number
    censored_number=data[np.where(data[:,1]==0)].shape[0]
    #max/min/mean survival time for censored data
    uncensored_number=data[np.where(data[:,1]==1)].shape[0]

    #max/min/mean survival time for censored data
    temp_data =data[np.where(data[:,1]==0),:][0]
    survival_time_max_censored = np.max(temp_data[:,0])
    survival_time_min_censored = np.min(temp_data[:,0])
    survival_time_mean_censored = np.mean(temp_data[:,0])


    #max/min/mean survival time for uncensored data
    temp_data =data[np.where(data[:,1]==1),:][0]
    survival_time_max_uncensored = np.max(temp_data[:,0])
    survival_time_min_uncensored = np.min(temp_data[:,0])
    survival_time_mean_uncensored = np.mean(temp_data[:,0])


    #max/min/mean/var feature value for all the data
    feature_max = data.max(axis=0)
    feature_max = np.delete(feature_max,[0,1,2])
    feature_min = data.min(axis=0)
    feature_min = np.delete(feature_min,[0,1,2])
    feature_mean = data.mean(axis=0)
    feature_mean = np.delete(feature_mean,[0,1,2])
    feature_var = data.var(axis=0)
    feature_var = np.delete(feature_var,[0,1,2])


    return censored_number, uncensored_number, survival_time_max_censored, survival_time_min_censored, survival_time_mean_censored, survival_time_max_uncensored, survival_time_min_uncensored, survival_time_mean_uncensored, feature_max, feature_min, feature_mean, feature_var

# %%
#folder = r"E:\git\robust-loss\miRNA dataset\Raw dataset (21 types)"
folder = r"/Users/a347429807/Desktop/miRNA_dataset"
onlyfiles = [f for f in listdir(folder) if isfile(join(folder, f)) and ".csv" in f]

# %%
for f in onlyfiles:
    filename= folder+"/"+f
    censored_number, uncensored_number, survival_time_max_censored, survival_time_min_censored, survival_time_mean_censored, survival_time_max_uncensored, survival_time_min_uncensored, survival_time_mean_uncensored, feature_max, feature_min, feature_mean, feature_var= Summary(filename)
    print(f)
    print("censored_number:  {}".format(censored_number))
    print("uncensored_number:  {}".format(uncensored_number))
    print("survival_time_max_censored:  {}".format(survival_time_max_censored))
    print("survival_time_min_censored:  {}".format(survival_time_min_censored))
    print("survival_time_mean_censored:  {}".format(survival_time_mean_censored))
    print("survival_time_max_uncensored:  {}".format(survival_time_max_uncensored))
    print("survival_time_min_uncensored:  {}".format(survival_time_min_uncensored))
    print("survival_time_mean_uncensored:  {}".format(survival_time_mean_uncensored))
    print("feature_max:  {}".format(feature_max))
    print("feature_min:  {}".format(feature_min))
    print("feature_mean:  {}".format(feature_mean))
    print("feature_var:  {}".format(feature_var))
    print("###############################")
# Out:
# UCS.csv
# censored_number:  22
# uncensored_number:  34
# survival_time_max_censored:  4269.0
# survival_time_min_censored:  0.0
# survival_time_mean_censored:  1183.409090909091
# survival_time_max_uncensored:  3115.0
# survival_time_min_uncensored:  8.0
# survival_time_mean_uncensored:  703.4411764705883
# feature_max:  [3.61135337 3.63603159 3.62821417 ... 2.85503257 3.50617384 3.52523561]
# feature_min:  [-1.13732841 -1.12193829 -1.14221726 ... -1.27029068 -0.92433591
#  -1.49936388]
# feature_mean:  [-6.34413157e-17  2.93416085e-16 -1.66533454e-16 ...  2.37904934e-17
#   1.98254112e-17 -1.48690584e-17]
# feature_var:  [0.98214286 0.98214286 0.98214286 ... 0.98214286 0.98214286 0.98214286]
# ###############################
# CHOL.csv
# censored_number:  18
# uncensored_number:  18
# survival_time_max_censored:  1976.0
# survival_time_min_censored:  10.0
# survival_time_mean_censored:  936.5555555555555
# survival_time_max_uncensored:  1939.0
# survival_time_min_uncensored:  21.0
# survival_time_mean_uncensored:  592.9444444444445
# feature_max:  [2.12435574 2.14063352 2.13984401 ... 3.45963618 2.08258732 2.4783589 ]
# feature_min:  [-1.7381638  -1.73861821 -1.73169044 ... -1.5139721  -1.44124998
#  -1.56974926]
# feature_mean:  [ 1.18539438e-16  6.24500451e-17 -1.01963191e-16 ... -3.51570624e-16
#   2.31296463e-16 -4.62592927e-16]
# feature_var:  [0.97222222 0.97222222 0.97222222 ... 0.97222222 0.97222222 0.97222222]
# ###############################
# STAD.csv
# censored_number:  235
# uncensored_number:  147
# survival_time_max_censored:  3720.0
# survival_time_min_censored:  0.0
# survival_time_mean_censored:  705.2085106382979
# survival_time_max_uncensored:  2197.0
# survival_time_min_uncensored:  3.0
# survival_time_mean_uncensored:  443.6938775510204
# feature_max:  [5.41357017 5.43369453 5.45119661 ... 4.98040986 7.05452427 9.68183812]
# feature_min:  [-1.49625486 -1.49374522 -1.49769864 ... -1.63857814 -0.68551451
#  -0.85578953]
# feature_mean:  [ 3.19697730e-18  2.08094159e-16 -1.27588458e-16 ... -1.81646437e-17
#   9.64905875e-17  3.37135788e-17]
# feature_var:  [0.9973822 0.9973822 0.9973822 ... 0.9973822 0.9973822 0.9973822]
# ###############################
# UCEC.csv
# censored_number:  338
# uncensored_number:  72
# survival_time_max_censored:  6859.0
# survival_time_min_censored:  -6.0
# survival_time_mean_censored:  1007.8343195266273
# survival_time_max_uncensored:  3349.0
# survival_time_min_uncensored:  50.0
# survival_time_mean_uncensored:  815.0138888888889
# feature_max:  [4.396196   4.39867606 4.42513226 ... 8.08524546 9.4987559  4.96162441]
# feature_min:  [-1.36542323 -1.36604089 -1.3690383  ... -1.40440446 -0.5961288
#  -1.25526493]
# feature_mean:  [-4.83353195e-17 -7.81217909e-17 -1.71272211e-16 ... -5.89636741e-17
#   3.16819741e-17  7.25706758e-17]
# feature_var:  [0.99756098 0.99756098 0.99756098 ... 0.99756098 0.99756098 0.99756098]
# ###############################
# BRCA.csv
# censored_number:  649
# uncensored_number:  105
# survival_time_max_censored:  5176.0
# survival_time_min_censored:  -7.0
# survival_time_mean_censored:  1139.8551617873652
# survival_time_max_uncensored:  6593.0
# survival_time_min_uncensored:  116.0
# survival_time_mean_uncensored:  1557.152380952381
# feature_max:  [ 8.63741798  8.62921845  8.63214672 ... 13.12707801 10.87890761
#   7.12460569]
# feature_min:  [-0.98931659 -0.98734395 -0.99052311 ... -1.22252282 -0.75376646
#  -1.11215565]
# feature_mean:  [-5.68639595e-17 -1.22304907e-17 -5.48485513e-17 ...  1.41722767e-17
#   1.28029034e-16 -2.39272204e-17]
# feature_var:  [0.99867374 0.99867374 0.99867374 ... 0.99867374 0.99867374 0.99867374]
# ###############################
# SKCM.csv
# censored_number:  71
# uncensored_number:  26
# survival_time_max_censored:  1785.0
# survival_time_min_censored:  -2.0
# survival_time_mean_censored:  514.2394366197183
# survival_time_max_uncensored:  1354.0
# survival_time_min_uncensored:  190.0
# survival_time_mean_uncensored:  529.9230769230769
# feature_max:  [4.77503673 4.7611651  4.76473882 ... 5.3443921  7.02900911 3.80688386]
# feature_min:  [-1.10407773 -1.10603179 -1.10209676 ... -1.37525906 -0.61464655
#  -1.35618233]
# feature_mean:  [-3.77704740e-16  1.14455982e-18  1.03582664e-16 ... -2.87856795e-16
#  -8.56989165e-17 -1.19034221e-16]
# feature_var:  [0.98969072 0.98969072 0.98969072 ... 0.98969072 0.98969072 0.98969072]
# ###############################
# MESO.csv
# censored_number:  13
# uncensored_number:  73
# survival_time_max_censored:  2359.0
# survival_time_min_censored:  -8.0
# survival_time_mean_censored:  1090.8461538461538
# survival_time_max_uncensored:  2790.0
# survival_time_min_uncensored:  20.0
# survival_time_mean_uncensored:  584.1369863013699
# feature_max:  [4.06564213 4.07828629 4.07880926 ... 3.94646776 5.7588754  5.99988276]
# feature_min:  [-1.0934616  -1.09539816 -1.08835355 ... -1.29256566 -0.94250958
#  -1.18476738]
# feature_mean:  [-2.45281831e-17  2.98856547e-16  2.13007906e-16 ...  3.46621956e-16
#  -8.26212483e-17  2.01389293e-16]
# feature_var:  [0.98837209 0.98837209 0.98837209 ... 0.98837209 0.98837209 0.98837209]
# ###############################
# PAAD.csv
# censored_number:  85
# uncensored_number:  93
# survival_time_max_censored:  2741.0
# survival_time_min_censored:  0.0
# survival_time_mean_censored:  692.3882352941176
# survival_time_max_uncensored:  2182.0
# survival_time_min_uncensored:  12.0
# survival_time_mean_uncensored:  454.3333333333333
# feature_max:  [5.88873584 5.88288515 5.90330211 ... 5.91481374 6.26651845 5.41149898]
# feature_min:  [-1.21320098 -1.21597158 -1.20911881 ... -1.16950209 -0.9525873
#  -1.44096912]
# feature_mean:  [ 2.18302280e-17 -7.67176584e-17  1.91482286e-16 ... -1.15388348e-16
#  -2.12065072e-17 -1.33476251e-16]
# feature_var:  [0.99438202 0.99438202 0.99438202 ... 0.99438202 0.99438202 0.99438202]
# ###############################
# BLCA.csv
# censored_number:  229
# uncensored_number:  178
# survival_time_max_censored:  5050.0
# survival_time_min_censored:  -64.0
# survival_time_mean_censored:  1019.5152838427948
# survival_time_max_uncensored:  3183.0
# survival_time_min_uncensored:  19.0
# survival_time_mean_uncensored:  557.1516853932584
# feature_max:  [ 5.164564    5.15513104  5.17206327 ...  7.08723949 15.12811282
#  14.24330614]
# feature_min:  [-1.26555488 -1.26897326 -1.26714278 ... -1.07474611 -0.47569845
#  -0.9054289 ]
# feature_mean:  [-6.12395747e-17 -2.18907611e-16  1.63669242e-18 ...  8.18346210e-19
#   3.76439257e-17  6.21943119e-17]
# feature_var:  [0.997543 0.997543 0.997543 ... 0.997543 0.997543 0.997543]
# ###############################
# KIRC.csv
# censored_number:  178
# uncensored_number:  76
# survival_time_max_censored:  4537.0
# survival_time_min_censored:  0.0
# survival_time_mean_censored:  1506.4494382022472
# survival_time_max_uncensored:  3615.0
# survival_time_min_uncensored:  41.0
# survival_time_mean_uncensored:  1060.8815789473683
# feature_max:  [6.01988927 6.0300912  6.01031853 ... 5.4275262  4.95991926 4.34501329]
# feature_min:  [-1.04309332 -1.04362874 -1.03942625 ... -1.13316815 -1.04078963
#  -1.60923077]
# feature_mean:  [-4.23982809e-17 -1.13644877e-17  1.63910880e-16 ...  1.29380321e-16
#   2.08494639e-16 -4.58950463e-17]
# feature_var:  [0.99606299 0.99606299 0.99606299 ... 0.99606299 0.99606299 0.99606299]
# ###############################
# KIRP.csv
# censored_number:  246
# uncensored_number:  44
# survival_time_max_censored:  5925.0
# survival_time_min_censored:  0.0
# survival_time_mean_censored:  1070.219512195122
# survival_time_max_uncensored:  2941.0
# survival_time_min_uncensored:  122.0
# survival_time_mean_uncensored:  989.7954545454545
# feature_max:  [5.28393319 5.26750174 5.26250401 ... 7.58205478 5.7466898  6.81122563]
# feature_min:  [-1.32010082 -1.32444252 -1.32118953 ... -1.44720659 -1.09106402
#  -1.28351906]
# feature_mean:  [-1.14946367e-16 -2.22523149e-17  3.16796398e-17 ...  1.01834250e-16
#  -5.58939868e-17  6.42206594e-17]
# feature_var:  [0.99655172 0.99655172 0.99655172 ... 0.99655172 0.99655172 0.99655172]
# ###############################
# LIHC.csv
# censored_number:  243
# uncensored_number:  128
# survival_time_max_censored:  3675.0
# survival_time_min_censored:  0.0
# survival_time_mean_censored:  885.6502057613169
# survival_time_max_uncensored:  3258.0
# survival_time_min_uncensored:  9.0
# survival_time_mean_uncensored:  657.7578125
# feature_max:  [5.48161941 5.43072416 5.44712856 ... 4.93609818 5.56323586 8.17100446]
# feature_min:  [-1.30207628 -1.3016049  -1.30263069 ... -1.15055065 -1.02804219
#  -0.73553269]
# feature_mean:  [ 3.47131727e-17  8.67829318e-18  1.49027242e-16 ...  1.49476119e-16
#  -4.48877234e-17 -1.53216762e-16]
# feature_var:  [0.99730458 0.99730458 0.99730458 ... 0.99730458 0.99730458 0.99730458]
# ###############################
# LGG.csv
# censored_number:  386
# uncensored_number:  124
# survival_time_max_censored:  6423.0
# survival_time_min_censored:  -1.0
# survival_time_mean_censored:  883.6683937823834
# survival_time_max_uncensored:  5166.0
# survival_time_min_uncensored:  7.0
# survival_time_mean_uncensored:  1203.032258064516
# feature_max:  [ 6.18846115  6.19305242  6.18723731 ... 13.70506079  6.70257918
#  10.32460633]
# feature_min:  [-1.49904492 -1.49944914 -1.50027446 ... -1.22024709 -1.24393536
#  -1.28101434]
# feature_mean:  [ 1.38777878e-16 -1.29308329e-16  1.91567894e-17 ...  9.20832038e-17
#  -1.00355454e-16  2.43813684e-17]
# feature_var:  [0.99803922 0.99803922 0.99803922 ... 0.99803922 0.99803922 0.99803922]
# ###############################
# SARC.csv
# censored_number:  161
# uncensored_number:  98
# survival_time_max_censored:  5723.0
# survival_time_min_censored:  15.0
# survival_time_mean_censored:  1389.9006211180124
# survival_time_max_uncensored:  2694.0
# survival_time_min_uncensored:  17.0
# survival_time_mean_uncensored:  866.0102040816327
# feature_max:  [ 4.9146738   4.88529377  4.88409344 ...  6.55645764  6.15118636
#  10.64997681]
# feature_min:  [-1.21521873 -1.21821109 -1.2162383  ... -1.15024919 -0.67441688
#  -0.88607958]
# feature_mean:  [ 1.55388358e-16 -1.14022905e-16 -1.67390769e-16 ... -9.05539050e-17
#  -7.54437268e-17 -9.68766037e-17]
# feature_var:  [0.996139 0.996139 0.996139 ... 0.996139 0.996139 0.996139]
# ###############################
# ACC.csv
# censored_number:  51
# uncensored_number:  29
# survival_time_max_censored:  4673.0
# survival_time_min_censored:  383.0
# survival_time_mean_censored:  1765.0588235294117
# survival_time_max_uncensored:  2405.0
# survival_time_min_uncensored:  125.0
# survival_time_mean_uncensored:  897.7241379310345
# feature_max:  [3.73723871 3.75083045 3.76485178 ... 5.76807317 3.57605223 3.54153727]
# feature_min:  [-1.43977007 -1.43680414 -1.43298309 ... -1.3003259  -0.95386253
#  -1.3975996 ]
# feature_mean:  [-1.70002901e-16  3.01841885e-16 -1.41206491e-16 ... -2.35922393e-16
#   5.55111512e-18 -9.99200722e-17]
# feature_var:  [0.9875 0.9875 0.9875 ... 0.9875 0.9875 0.9875]
# ###############################
# LUAD.csv
# censored_number:  284
# uncensored_number:  157
# survival_time_max_censored:  7248.0
# survival_time_min_censored:  0.0
# survival_time_mean_censored:  951.887323943662
# survival_time_max_uncensored:  4961.0
# survival_time_min_uncensored:  4.0
# survival_time_mean_uncensored:  802.4585987261147
# feature_max:  [ 4.55871068  4.55930303  4.52204212 ...  8.00093944 11.50451896
#  17.88838622]
# feature_min:  [-1.30652267 -1.30539246 -1.30585642 ... -1.06853339 -0.92802706
#  -0.6217144 ]
# feature_mean:  [-1.12281059e-16 -9.28962123e-17 -9.88123667e-17 ...  1.59358543e-16
#  -5.03502505e-19  1.45763975e-16]
# feature_var:  [0.99773243 0.99773243 0.99773243 ... 0.99773243 0.99773243 0.99773243]
# ###############################
# ESCA.csv
# censored_number:  107
# uncensored_number:  77
# survival_time_max_censored:  3714.0
# survival_time_min_censored:  4.0
# survival_time_mean_censored:  571.8317757009346
# survival_time_max_uncensored:  2532.0
# survival_time_min_uncensored:  9.0
# survival_time_mean_uncensored:  495.1818181818182
# feature_max:  [7.15188618 7.16162652 7.14430182 ... 7.51442759 4.84259575 4.08091733]
# feature_min:  [-1.12530285 -1.12317019 -1.13384521 ... -1.18569173 -0.81517654
#  -1.29774556]
# feature_mean:  [ 7.22550039e-17 -1.74980803e-17 -1.62913161e-17 ...  3.25826322e-17
#  -6.60703376e-17 -1.74980803e-17]
# feature_var:  [0.99456522 0.99456522 0.99456522 ... 0.99456522 0.99456522 0.99456522]
# ###############################
# HNSC.csv
# censored_number:  281
# uncensored_number:  203
# survival_time_max_censored:  5480.0
# survival_time_min_censored:  11.0
# survival_time_mean_censored:  1026.8540925266905
# survival_time_max_uncensored:  6417.0
# survival_time_min_uncensored:  2.0
# survival_time_mean_uncensored:  745.1379310344828
# feature_max:  [5.05235943 5.06922995 5.09446551 ... 4.96310648 8.95656214 5.54232288]
# feature_min:  [-1.42244978 -1.42215569 -1.41941203 ... -1.56621479 -0.61340095
#  -1.35108457]
# feature_mean:  [ 4.76690542e-17 -2.51319856e-16 -1.76970468e-16 ...  1.15380616e-16
#   2.04152581e-17 -1.88095636e-16]
# feature_var:  [0.99793388 0.99793388 0.99793388 ... 0.99793388 0.99793388 0.99793388]
# ###############################
# UVM.csv
# censored_number:  57
# uncensored_number:  23
# survival_time_max_censored:  2600.0
# survival_time_min_censored:  4.0
# survival_time_mean_censored:  861.8771929824561
# survival_time_max_uncensored:  1581.0
# survival_time_min_uncensored:  40.0
# survival_time_mean_uncensored:  693.8695652173913
# feature_max:  [3.86794965 3.87879902 3.87036737 ... 5.59489509 4.0949402  3.11093656]
# feature_min:  [-1.27453722 -1.27414269 -1.27210602 ... -1.40122754 -1.07135888
#  -1.52219866]
# feature_mean:  [-1.24900090e-17  1.04083409e-16 -1.65145675e-16 ... -2.53963517e-16
#  -2.11983209e-16  1.46410661e-16]
# feature_var:  [0.9875 0.9875 0.9875 ... 0.9875 0.9875 0.9875]
# ###############################
# LUSC.csv
# censored_number:  201
# uncensored_number:  137
# survival_time_max_censored:  4765.0
# survival_time_min_censored:  0.0
# survival_time_mean_censored:  979.2139303482587
# survival_time_max_uncensored:  3838.0
# survival_time_min_uncensored:  1.0
# survival_time_mean_uncensored:  857.5182481751825
# feature_max:  [6.86159568 6.8453267  6.83671938 ... 4.84145248 6.50178794 6.10448185]
# feature_min:  [-1.54151947 -1.54058902 -1.5360801  ... -1.5146679  -0.91822109
#  -1.24364101]
# feature_mean:  [-1.37792473e-16 -2.56205313e-17 -9.41061824e-17 ... -2.77555756e-17
#   8.91791572e-17 -1.18494957e-16]
# feature_var:  [0.99704142 0.99704142 0.99704142 ... 0.99704142 0.99704142 0.99704142]
# ###############################
# CESC.csv
# censored_number:  235
# uncensored_number:  72
# survival_time_max_censored:  6408.0
# survival_time_min_censored:  0.0
# survival_time_mean_censored:  1070.7531914893616
# survival_time_max_uncensored:  4086.0
# survival_time_min_uncensored:  14.0
# survival_time_mean_uncensored:  881.3194444444445
# feature_max:  [3.83871424 3.83556638 3.82236973 ... 4.36904752 7.19896088 3.9045487 ]
# feature_min:  [-1.42182958 -1.41950675 -1.42226628 ... -1.48607083 -0.78174858
#  -1.26028281]
# feature_mean:  [-8.10065008e-17  3.90567058e-17 -5.26180619e-17 ... -1.35613562e-16
#   1.05959396e-16 -1.13915392e-17]
# feature_var:  [0.99674267 0.99674267 0.99674267 ... 0.99674267 0.99674267 0.99674267]
# ###############################

# %%
column_name=['Cancer_type','censored_count','uncensored_count','censored_survival_time_max', 'censored_survival_time_min', 'censored_survival_time_mean',
             'uncensored_survival_time_max', 'uncensored_survival_time_min', 'uncensored_survival_time_mean']
for i in range(1046):
    column_name.append('fea_'+str(i+1)+'_max')
    column_name.append('fea_'+str(i+1)+'_min')
    column_name.append('fea_'+str(i+1)+'_mean')
    column_name.append('fea_'+str(i+1)+'_var')

df = pd.DataFrame( columns = column_name)
for f in onlyfiles:
    filename= folder+"\\"+f
    censored_number, uncensored_number, survival_time_max_censored, survival_time_min_censored, survival_time_mean_censored, survival_time_max_uncensored, survival_time_min_uncensored, survival_time_mean_uncensored, feature_max, feature_min, feature_mean, feature_var= Summary(filename)
    to_append = [f[:-4],censored_number, uncensored_number, survival_time_max_censored, survival_time_min_censored, survival_time_mean_censored, survival_time_max_uncensored, survival_time_min_uncensored, survival_time_mean_uncensored]
    to_append +=list(feature_max)+ list(feature_min)+ list(feature_mean)+ list(feature_var)
    a_series = pd.Series(to_append, index = df.columns)
    df = df.append(a_series, ignore_index=True)

# %%
df
# Out:
#    Cancer_type censored_count uncensored_count  censored_survival_time_max  \
# 0          ACC             51               29                      4673.0
# 1         BLCA            229              178                      5050.0
# 2         BRCA            649              105                      5176.0
# 3         CESC            235               72                      6408.0
# 4         CHOL             18               18                      1976.0
# 5         ESCA            107               77                      3714.0
# 6         HNSC            281              203                      5480.0
# 7         KIRC            178               76                      4537.0
# 8         KIRP            246               44                      5925.0
# 9          LGG            386              124                      6423.0
# 10        LIHC            243              128                      3675.0
# 11        LUAD            284              157                      7248.0
# 12        LUSC            201              137                      4765.0
# 13        MESO             13               73                      2359.0
# 14        PAAD             85               93                      2741.0
# 15        SARC            161               98                      5723.0
# 16        SKCM             71               26                      1785.0
# 17        STAD            235              147                      3720.0
# 18        UCEC            338               72                      6859.0
# 19         UCS             22               34                      4269.0
# 20         UVM             57               23                      2600.0
#
#     censored_survival_time_min  censored_survival_time_mean  \
# 0                        383.0                  1765.058824
# 1                        -64.0                  1019.515284
# 2                         -7.0                  1139.855162
# 3                          0.0                  1070.753191
# 4                         10.0                   936.555556
# 5                          4.0                   571.831776
# 6                         11.0                  1026.854093
# 7                          0.0                  1506.449438
# 8                          0.0                  1070.219512
# 9                         -1.0                   883.668394
# 10                         0.0                   885.650206
# 11                         0.0                   951.887324
# 12                         0.0                   979.213930
# 13                        -8.0                  1090.846154
# 14                         0.0                   692.388235
# 15                        15.0                  1389.900621
# 16                        -2.0                   514.239437
# 17                         0.0                   705.208511
# 18                        -6.0                  1007.834320
# 19                         0.0                  1183.409091
# 20                         4.0                   861.877193
#
#     uncensored_survival_time_max  uncensored_survival_time_min  \
# 0                         2405.0                         125.0
# 1                         3183.0                          19.0
# 2                         6593.0                         116.0
# 3                         4086.0                          14.0
# 4                         1939.0                          21.0
# 5                         2532.0                           9.0
# 6                         6417.0                           2.0
# 7                         3615.0                          41.0
# 8                         2941.0                         122.0
# 9                         5166.0                           7.0
# 10                        3258.0                           9.0
# 11                        4961.0                           4.0
# 12                        3838.0                           1.0
# 13                        2790.0                          20.0
# 14                        2182.0                          12.0
# 15                        2694.0                          17.0
# 16                        1354.0                         190.0
# 17                        2197.0                           3.0
# 18                        3349.0                          50.0
# 19                        3115.0                           8.0
# 20                        1581.0                          40.0
#
#     uncensored_survival_time_mean  fea_1_max  ...  fea_1044_mean  \
# 0                      897.724138   3.737239  ...       0.000000
# 1                      557.151685   5.164564  ...       0.997543
# 2                     1557.152381   8.637418  ...       0.000000
# 3                      881.319444   3.838714  ...       0.000000
# 4                      592.944444   2.124356  ...       0.000000
# 5                      495.181818   7.151886  ...       0.000000
# 6                      745.137931   5.052359  ...       0.997934
# 7                     1060.881579   6.019889  ...       0.996063
# 8                      989.795455   5.283933  ...       0.996552
# 9                     1203.032258   6.188461  ...       0.000000
# 10                     657.757812   5.481619  ...       0.000000
# 11                     802.458599   4.558711  ...       0.997732
# 12                     857.518248   6.861596  ...       0.000000
# 13                     584.136986   4.065642  ...       0.000000
# 14                     454.333333   5.888736  ...       0.000000
# 15                     866.010204   4.914674  ...       0.996139
# 16                     529.923077   4.775037  ...       0.000000
# 17                     443.693878   5.413570  ...       0.000000
# 18                     815.013889   4.396196  ...       0.997561
# 19                     703.441176   3.611353  ...       0.000000
# 20                     693.869565   3.867950  ...       0.000000
#
#     fea_1044_var  fea_1045_max  fea_1045_min  fea_1045_mean  fea_1045_var  \
# 0            0.0      0.987500      0.987500       0.987500      0.987500
# 1            0.0      0.997543      0.997543       0.997543      0.997543
# 2            0.0      0.998674      0.998674       0.998674      0.998674
# 3            0.0      0.996743      0.996743       0.996743      0.996743
# 4            0.0      0.972222      0.972222       0.972222      0.972222
# 5            0.0      0.994565      0.994565       0.994565      0.994565
# 6            0.0      0.997934      0.997934       0.997934      0.997934
# 7            0.0      0.996063      0.996063       0.996063      0.996063
# 8            0.0      0.996552      0.996552       0.996552      0.996552
# 9            0.0      0.998039      0.998039       0.998039      0.998039
# 10           0.0      0.997305      0.997305       0.997305      0.997305
# 11           0.0      0.997732      0.997732       0.997732      0.997732
# 12           0.0      0.997041      0.997041       0.997041      0.997041
# 13           0.0      0.988372      0.988372       0.988372      0.988372
# 14           0.0      0.994382      0.994382       0.994382      0.994382
# 15           0.0      0.996139      0.996139       0.996139      0.996139
# 16           0.0      0.989691      0.989691       0.989691      0.989691
# 17           0.0      0.997382      0.997382       0.997382      0.997382
# 18           0.0      0.997561      0.997561       0.997561      0.997561
# 19           0.0      0.982143      0.982143       0.982143      0.982143
# 20           0.0      0.987500      0.987500       0.987500      0.987500
#
#     fea_1046_max  fea_1046_min  fea_1046_mean  fea_1046_var
# 0       0.987500      0.987500       0.987500      0.987500
# 1       0.997543      0.997543       0.997543      0.997543
# 2       0.998674      0.998674       0.998674      0.998674
# 3       0.996743      0.996743       0.996743      0.996743
# 4       0.972222      0.972222       0.972222      0.972222
# 5       0.994565      0.994565       0.994565      0.994565
# 6       0.997934      0.997934       0.997934      0.997934
# 7       0.996063      0.996063       0.996063      0.996063
# 8       0.996552      0.996552       0.996552      0.996552
# 9       0.998039      0.998039       0.998039      0.998039
# 10      0.997305      0.997305       0.997305      0.997305
# 11      0.997732      0.997732       0.997732      0.997732
# 12      0.997041      0.997041       0.997041      0.997041
# 13      0.988372      0.988372       0.988372      0.988372
# 14      0.994382      0.994382       0.994382      0.994382
# 15      0.996139      0.996139       0.996139      0.996139
# 16      0.989691      0.989691       0.989691      0.989691
# 17      0.997382      0.997382       0.997382      0.997382
# 18      0.997561      0.997561       0.997561      0.997561
# 19      0.982143      0.982143       0.982143      0.982143
# 20      0.987500      0.987500       0.987500      0.987500
#
# [21 rows x 4193 columns]

# %%
df.to_csv("data.csv")

# %%
def feature_mean_plot(filename, feature_num, properties):
  with open(filename,'rt') as raw_data:
    data=np.loadtxt(raw_data,dtype=str,delimiter=',')
  
  cancer_distribution=[]
  for i in range(len(data[0])):
    if data[0][i]=='fea_'+ str(feature_num)+ '_'+ properties:
      print("i={}".format(i))
      cancer_distribution.append(data[1:,i])
  cancer_distribution = np.array(cancer_distribution).astype('float64')
  print(cancer_distribution)
  plt.plot(np.linspace(1,21,21),cancer_distribution[0],marker='^')
  plt.show()

# %%
feature_mean_plot('data.csv',10,'mean')
# Out:
# i=48
# [[ 4.005168    8.28234823 10.00948321  8.72279925  4.3576043   3.95497136
#    7.68574929 11.20285397  6.8680503   6.83427851 11.05829496 10.16542784
#    8.64401068  4.69045223  7.70841171  7.3331259   4.68055623  8.71029343
#    6.77108575  4.17314268  6.61134392]]
